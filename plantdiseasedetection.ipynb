# %%
# Import required libraries

import os
import random
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from PIL import Image

# %%
dataset_path = "/kaggle/input/datasets/abdallahalidev/plantvillage-dataset/color"

# %%
# Get all folder names (classes)

class_names = os.listdir(dataset_path)

print("Number of Classes:", len(class_names))
print(class_names)
# Out:
# Number of Classes: 38
# ['Tomato___Late_blight', 'Tomato___healthy', 'Grape___healthy', 'Orange___Haunglongbing_(Citrus_greening)', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Potato___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Early_blight', 'Tomato___Septoria_leaf_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Strawberry___Leaf_scorch', 'Peach___healthy', 'Apple___Apple_scab', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Bacterial_spot', 'Apple___Black_rot', 'Blueberry___healthy', 'Cherry_(including_sour)___Powdery_mildew', 'Peach___Bacterial_spot', 'Apple___Cedar_apple_rust', 'Tomato___Target_Spot', 'Pepper,_bell___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Potato___Late_blight', 'Tomato___Tomato_mosaic_virus', 'Strawberry___healthy', 'Apple___healthy', 'Grape___Black_rot', 'Potato___Early_blight', 'Cherry_(including_sour)___healthy', 'Corn_(maize)___Common_rust_', 'Grape___Esca_(Black_Measles)', 'Raspberry___healthy', 'Tomato___Leaf_Mold', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___healthy']

# %%
# Count images in every folder
for class_name in class_names:
    folder_path = os.path.join(dataset_path,class_name)
    total_images = len(os.listdir(folder_path))
    print(class_name,":",total_images)
# Out:
# Tomato___Late_blight : 1909
# Tomato___healthy : 1591
# Grape___healthy : 423
# Orange___Haunglongbing_(Citrus_greening) : 5507
# Soybean___healthy : 5090
# Squash___Powdery_mildew : 1835
# Potato___healthy : 152
# Corn_(maize)___Northern_Leaf_Blight : 985
# Tomato___Early_blight : 1000
# Tomato___Septoria_leaf_spot : 1771
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot : 513
# Strawberry___Leaf_scorch : 1109
# Peach___healthy : 360
# Apple___Apple_scab : 630
# Tomato___Tomato_Yellow_Leaf_Curl_Virus : 5357
# Tomato___Bacterial_spot : 2127
# Apple___Black_rot : 621
# Blueberry___healthy : 1502
# Cherry_(including_sour)___Powdery_mildew : 1052
# Peach___Bacterial_spot : 2297
# Apple___Cedar_apple_rust : 275
# Tomato___Target_Spot : 1404
# Pepper,_bell___healthy : 1478
# Grape___Leaf_blight_(Isariopsis_Leaf_Spot) : 1076
# Potato___Late_blight : 1000
# Tomato___Tomato_mosaic_virus : 373
# Strawberry___healthy : 456
# Apple___healthy : 1645
# Grape___Black_rot : 1180
# Potato___Early_blight : 1000
# Cherry_(including_sour)___healthy : 854
# Corn_(maize)___Common_rust_ : 1192
# Grape___Esca_(Black_Measles) : 1383
# Raspberry___healthy : 371
# Tomato___Leaf_Mold : 952
# Tomato___Spider_mites Two-spotted_spider_mite : 1676
# Pepper,_bell___Bacterial_spot : 997
# Corn_(maize)___healthy : 1162

# %%
# Get all class names

class_names = os.listdir(dataset_path)

total = 0

for class_name in class_names:

    folder_path = os.path.join(dataset_path, class_name)

    total += len(os.listdir(folder_path))

print("Total Images:", total)
# Out:
# Total Images: 54305

# %%
classes = []
counts = []

for class_name in class_names:
    folder_path = os.path.join(dataset_path,class_name)
    image_count = len(os.listdir(folder_path))
    classes.append(class_name)
    counts.append(image_count)

#Plot
plt.figure(figsize=(15,6))
plt.bar(classes,counts)
plt.xticks(rotation=90)
plt.xlabel("Classes")
plt.ylabel("Number of Images")
plt.title("Images in Each Class")
plt.show()

# %%
plt.figure(figsize=(10,10))
for i in range(9):
    class_name = random.choice(class_names)
    folder_path = os.path.join(dataset_path,class_name)
    image_name = random.choice(os.listdir(folder_path))
    image_path = os.path.join(folder_path,image_name)
    img = Image.open(image_path)
    plt.subplot(3,3,i+1)
    plt.imshow(img)
    plt.title

# %% [markdown]
# IMAGE SIZE

# %%
for class_name in class_names[:5]:
    folder_path = os.path.join(dataset_path,class_name)
    image_name = random.choice(os.listdir(folder_path))
    image_path = os.path.join(folder_path,image_name)
    img = Image.open(image_path)
    print(class_name)
    print("Image Size :",img.size)
    print("_"*40)
# Out:
# Tomato___Late_blight
# Image Size : (256, 256)
# ________________________________________
# Tomato___healthy
# Image Size : (256, 256)
# ________________________________________
# Grape___healthy
# Image Size : (256, 256)
# ________________________________________
# Orange___Haunglongbing_(Citrus_greening)
# Image Size : (256, 256)
# ________________________________________
# Soybean___healthy
# Image Size : (256, 256)
# ________________________________________

# %% [markdown]
# IMAGE FORMAT

# %%
for class_name in class_names[:5]:
    folder_path = os.path.join(dataset_path,class_name)
    image_name= random.choice(os.listdir(folder_path))
    image_path = os.path.join(folder_path,image_name)
    img = Image.open(image_path)
    print(class_name)
    print("Formate:",img.format)
# Out:
# Tomato___Late_blight
# Formate: JPEG
# Tomato___healthy
# Formate: JPEG
# Grape___healthy
# Formate: JPEG
# Orange___Haunglongbing_(Citrus_greening)
# Formate: JPEG
# Soybean___healthy
# Formate: JPEG

# %% [markdown]
# One Image with Details

# %%
class_name = random.choice(class_names)
folder_path = os.path.join(dataset_path,class_name)
image_name = random.choice(os.listdir(folder_path))
image_path = os.path.join(folder_path,image_name)
img = Image.open(image_path)
plt.imshow(img)
plt.title(class_name)
plt.axis("off")
plt.show()
print("Image Name :", image_name)
print("image Size :", img.size)
print("Image Formate :",img.format)
# Out:
# Image Name : 16826b8c-034f-4db2-bd96-db82b5b26c67___Com.G_SpM_FL 1551.JPG
# image Size : (256, 256)
# Image Formate : JPEG

# %% [markdown]
# # *DATA CLEANING**

# %% [markdown]
# Corrupted Images

# %%
from PIL import Image
corrupted_images = 0

for class_name in class_names:

    folder_path = os.path.join(dataset_path, class_name)

    for image_name in os.listdir(folder_path):

        image_path = os.path.join(folder_path, image_name)

        try:
            img = Image.open(image_path)   # Correct
            img.verify()

        except Exception:
            corrupted_images += 1

print("Corrupted Images:", corrupted_images)
# Out:
# Corrupted Images: 0

# %%
# Image size

IMG_SIZE = (224, 224)

# Batch size

BATCH_SIZE = 32

# Number of classes

NUM_CLASSES = len(class_names)

print("Image Size :", IMG_SIZE)
print("Batch Size :", BATCH_SIZE)
print("Number of Classes :", NUM_CLASSES)
# Out:
# Image Size : (224, 224)
# Batch Size : 32
# Number of Classes : 38

# %% [markdown]
# Data Preprossing

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split = 0.2,
    subset = "training",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
    
)
# Out:
# Found 54305 files belonging to 38 classes.
# Using 43444 files for training.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1783286378.488629      25 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13756 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1783286378.491935      25 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13756 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    dataset_path,
    validation_split = 0.2,
    subset="validation",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 54305 files belonging to 38 classes.
# Using 10861 files for validation.

# %%
print("Trainning Batches :", len(train_dataset))
print("Validation Batches :", len(validation_dataset))
# Out:
# Trainning Batches : 1358
# Validation Batches : 340

# %%
for images, labels in train_dataset.take(1):

    print("Image Batch Shape :", images.shape)
    print("Label Batch Shape :", labels.shape)
# Out:
# Image Batch Shape : (32, 224, 224, 3)
# Label Batch Shape : (32,)

# %%
plt.figure(figsize=(10,10))

for images, labels in train_dataset.take(1):

    for i in range(9):

        plt.subplot(3,3,i+1)

        plt.imshow(images[i].numpy().astype("uint8"))

        plt.title(class_names[labels[i]])

        plt.axis("off")

plt.show()

# %%
for images, labels in train_dataset.take(1):

    print("Minimum Pixel Value :", images.numpy().min())
    print("Maximum Pixel Value :", images.numpy().max())
# Out:
# Minimum Pixel Value : 0.0
# Maximum Pixel Value : 254.23973

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)

validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)

# %%
# Data Augmentation

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2)
])

# %%
plt.figure(figsize=(10, 10))

for images, labels in train_dataset.take(1):

    first_image = images[0]

    for i in range(9):

        ax = plt.subplot(3, 3, i + 1)

        augmented_image = data_augmentation(tf.expand_dims(first_image, 0))

        plt.imshow(augmented_image[0])

        plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.027682839..217.89952].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.16028649..217.01869].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.081685804..224.03719].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.2911909..224.51352].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10361058..218.50922].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.22734924..220.05074].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.29010028..220.31873].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06867063..223.62007].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.049155187..216.60641].

# %% [markdown]
# Build Baseline CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import MaxPooling2D
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
cnn_model = Sequential()

# First Convolution Block
cnn_model.add(
    Conv2D(
        filters=32,
        kernel_size=(3,3),
        activation="relu",
        input_shape=(224,224,3)
    )
)

cnn_model.add(MaxPooling2D(pool_size=(2,2)))

# Second Block
cnn_model.add(
    Conv2D(
        filters=64,
        kernel_size=(3,3),
        activation="relu"
    )
)

cnn_model.add(MaxPooling2D(pool_size=(2,2)))

# Third Block
cnn_model.add(
    Conv2D(
        filters=128,
        kernel_size=(3,3),
        activation="relu"
    )
)

cnn_model.add(MaxPooling2D(pool_size=(2,2)))

# Flatten
cnn_model.add(Flatten())

# Dense Layer
cnn_model.add(Dense(256, activation="relu"))

cnn_model.add(Dropout(0.5))

# Output Layer
cnn_model.add(Dense(NUM_CLASSES, activation="softmax"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 86528)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │    22,151,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 38)             │         9,766 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,254,438 (84.89 MB)
#  Trainable params: 22,254,438 (84.89 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
cnn_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=3,
    restore_best_weights=True
)

checkpoint = tf.keras.callbacks.ModelCheckpoint(
    "cnn_model.keras",
    save_best_only=True
)

# %%
history = cnn_model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=20,
    callbacks=[early_stopping, checkpoint]
)
# Out:
# Epoch 1/20
# 2026-07-05 21:19:54.667505: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:54.828734: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:54.987152: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:55.142748: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:55.300588: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:55.459466: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:55.480578: E external/local_xla/xla/service/slow_operation_alarm.cc:73] Trying algorithm eng4{k11=1} for conv (f32[32,32,111,111]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,109,109]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
# 2026-07-05 21:19:55.618561: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:55.778024: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:19:55.802081: E external/local_xla/xla/service/slow_operation_alarm.cc:140] The operation took 1.321577668s
# Trying algorithm eng4{k11=1} for conv (f32[32,32,111,111]{3,2,1,0}, u8[0]{0}) custom-call(f32[32,64,109,109]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBackwardInput", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]} is taking a while...
#    4/1358 ━━━━━━━━━━━━━━━━━━━━ 1:07 50ms/step - accuracy: 0.0234 - loss: 616.6327
# I0000 00:00:1783286398.899494      83 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1356/1358 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2560 - loss: 17.9313
# 2026-07-05 21:21:07.248811: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:21:07.407042: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-07-05 21:21:07.560537: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 89s 59ms/step - accuracy: 0.3116 - loss: 4.9739 - val_accuracy: 0.4059 - val_loss: 2.1881
# Epoch 2/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 78s 57ms/step - accuracy: 0.4601 - loss: 1.9479 - val_accuracy: 0.5983 - val_loss: 1.3891
# Epoch 3/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 79s 58ms/step - accuracy: 0.6173 - loss: 1.3340 - val_accuracy: 0.7403 - val_loss: 0.9149
# Epoch 4/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 79s 58ms/step - accuracy: 0.7501 - loss: 0.8369 - val_accuracy: 0.8069 - val_loss: 0.6601
# Epoch 5/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 79s 58ms/step - accuracy: 0.8248 - loss: 0.5765 - val_accuracy: 0.8407 - val_loss: 0.5442
# Epoch 6/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 77s 57ms/step - accuracy: 0.8504 - loss: 0.4960 - val_accuracy: 0.7914 - val_loss: 0.7364
# Epoch 7/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 78s 57ms/step - accuracy: 0.8727 - loss: 0.4153 - val_accuracy: 0.8492 - val_loss: 0.5137
# Epoch 8/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 78s 57ms/step - accuracy: 0.8996 - loss: 0.3235 - val_accuracy: 0.8688 - val_loss: 0.5003
# Epoch 9/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 76s 56ms/step - accuracy: 0.9155 - loss: 0.2818 - val_accuracy: 0.8599 - val_loss: 0.5406
# Epoch 10/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 76s 56ms/step - accuracy: 0.9189 - loss: 0.2725 - val_accuracy: 0.8429 - val_loss: 0.6626
# Epoch 11/20
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 77s 56ms/step - accuracy: 0.9306 - loss: 0.2376 - val_accuracy: 0.8719 - val_loss: 0.5519

# %%
loss, accuracy = cnn_model.evaluate(validation_dataset)

print("Validation Loss :", loss)
print("Validation Accuracy :", accuracy)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8688 - loss: 0.5003
# Validation Loss : 0.5003324747085571
# Validation Accuracy : 0.8687965869903564

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["accuracy"], label="Training Accuracy")

plt.plot(history.history["val_accuracy"], label="Validation Accuracy")

plt.xlabel("Epoch")

plt.ylabel("Accuracy")

plt.title("CNN Accuracy")

plt.legend()

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.plot(history.history["loss"], label="Training Loss")

plt.plot(history.history["val_loss"], label="Validation Loss")

plt.xlabel("Epoch")

plt.ylabel("Loss")

plt.title("CNN Loss")

plt.legend()

plt.show()

# %%
predictions = cnn_model.predict(validation_dataset)

predicted_labels = np.argmax(predictions, axis=1)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step

# %%
true_labels = []

for images, labels in validation_dataset:
    true_labels.extend(labels.numpy())

true_labels = np.array(true_labels)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(12,10))

sns.heatmap(cm, cmap="Blues")

plt.title("Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
from sklearn.metrics import classification_report

print(
    classification_report(
        true_labels,
        predicted_labels,
        target_names=class_names
    )
)
# Out:
#                                                     precision    recall  f1-score   support
#
#                               Tomato___Late_blight       0.01      0.01      0.01       126
#                                   Tomato___healthy       0.02      0.02      0.02       132
#                                    Grape___healthy       0.03      0.02      0.02        55
#           Orange___Haunglongbing_(Citrus_greening)       0.03      0.03      0.03       329
#                                  Soybean___healthy       0.03      0.03      0.03       295
#                            Squash___Powdery_mildew       0.03      0.03      0.03       232
#                                   Potato___healthy       0.01      0.01      0.01       167
#                Corn_(maize)___Northern_Leaf_Blight       0.00      0.00      0.00       108
#                              Tomato___Early_blight       0.02      0.02      0.02       219
#                        Tomato___Septoria_leaf_spot       0.01      0.01      0.01       195
# Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot       0.01      0.01      0.01       227
#                           Strawberry___Leaf_scorch       0.03      0.03      0.03       274
#                                    Peach___healthy       0.03      0.03      0.03       268
#                                 Apple___Apple_scab       0.01      0.01      0.01       222
#             Tomato___Tomato_Yellow_Leaf_Curl_Virus       0.01      0.01      0.01        85
#                            Tomato___Bacterial_spot       0.10      0.10      0.10      1106
#                                  Apple___Black_rot       0.04      0.03      0.03       466
#                                Blueberry___healthy       0.01      0.01      0.01        81
#           Cherry_(including_sour)___Powdery_mildew       0.03      0.02      0.03       217
#                             Peach___Bacterial_spot       0.02      0.02      0.02       294
#                           Apple___Cedar_apple_rust       0.02      0.02      0.02       203
#                               Tomato___Target_Spot       0.03      0.04      0.04       202
#                             Pepper,_bell___healthy       0.00      0.00      0.00        25
#         Grape___Leaf_blight_(Isariopsis_Leaf_Spot)       0.00      0.00      0.00        76
#                               Potato___Late_blight       0.09      0.09      0.09       999
#                       Tomato___Tomato_mosaic_virus       0.05      0.05      0.05       359
#                               Strawberry___healthy       0.01      0.02      0.02       229
#                                    Apple___healthy       0.00      0.00      0.00        95
#                                  Grape___Black_rot       0.04      0.03      0.03       438
#                              Potato___Early_blight       0.03      0.02      0.03       186
#                  Cherry_(including_sour)___healthy       0.02      0.02      0.02       376
#                        Corn_(maize)___Common_rust_       0.03      0.02      0.02       189
#                       Grape___Esca_(Black_Measles)       0.04      0.04      0.04       335
#                                Raspberry___healthy       0.02      0.02      0.02       334
#                                 Tomato___Leaf_Mold       0.01      0.01      0.01       279
#      Tomato___Spider_mites Two-spotted_spider_mite       0.09      0.09      0.09      1044
#                      Pepper,_bell___Bacterial_spot       0.02      0.01      0.01        77
#                             Corn_(maize)___healthy       0.04      0.04      0.04       317
#
#                                           accuracy                           0.05     10861
#                                          macro avg       0.03      0.03      0.03     10861
#                                       weighted avg       0.05      0.05      0.05     10861

# %%
cnn_model.save("plant_disease_cnn.keras")

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications.efficientnet import preprocess_input

from tensorflow.keras.models import Sequential

from tensorflow.keras.layers import (
    GlobalAveragePooling2D,
    Dense,
    Dropout,
    Lambda
)

# %%
base_model = EfficientNetB0(
    weights="imagenet",
    include_top=False,
    input_shape=(224,224,3)
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
base_model.trainable = False

print("Trainable :", base_model.trainable)
# Out:
# Trainable : False

# %%
transfer_model = Sequential([

    data_augmentation,

    Lambda(preprocess_input),

    base_model,

    GlobalAveragePooling2D(),

    Dense(256, activation="relu"),

    Dropout(0.3),

    Dense(NUM_CLASSES, activation="softmax")

])

# %%
transfer_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (1, 224, 224, 3)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (1, 224, 224, 3)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (1, 7, 7, 1280)        │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (1, 1280)              │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (1, 256)               │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (1, 256)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (1, 38)                │         9,766 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,387,273 (16.74 MB)
#  Trainable params: 337,702 (1.29 MB)
#  Non-trainable params: 4,049,571 (15.45 MB)

# %%
transfer_model.compile(

    optimizer="adam",

    loss="sparse_categorical_crossentropy",

    metrics=["accuracy"]

)

# %%
checkpoint_transfer = tf.keras.callbacks.ModelCheckpoint(

    "efficientnet_model.keras",

    save_best_only=True

)

early_stop = tf.keras.callbacks.EarlyStopping(

    monitor="val_loss",

    patience=3,

    restore_best_weights=True

)

# %%
history_transfer = transfer_model.fit(

    train_dataset,

    validation_data=validation_dataset,

    epochs=5,

    callbacks=[checkpoint_transfer, early_stop]

)
# Out:
# Epoch 1/5
# E0000 00:00:1783287309.052302      25 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_2_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 141s 95ms/step - accuracy: 0.8558 - loss: 0.4955 - val_accuracy: 0.9441 - val_loss: 0.1769
# Epoch 2/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 124s 92ms/step - accuracy: 0.9299 - loss: 0.2153 - val_accuracy: 0.9434 - val_loss: 0.1788
# Epoch 3/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 125s 92ms/step - accuracy: 0.9417 - loss: 0.1749 - val_accuracy: 0.9538 - val_loss: 0.1434
# Epoch 4/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 125s 92ms/step - accuracy: 0.9481 - loss: 0.1547 - val_accuracy: 0.9448 - val_loss: 0.1621
# Epoch 5/5
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 125s 92ms/step - accuracy: 0.9500 - loss: 0.1465 - val_accuracy: 0.9585 - val_loss: 0.1236

# %%
base_model.trainable = True

# %%
for layer in base_model.layers[:-10]:

    layer.trainable = False

# %%
print("Trainable Layers")

for layer in base_model.layers[-10:]:

    print(layer.name, layer.trainable)
# Out:
# Trainable Layers
# block7a_se_squeeze True
# block7a_se_reshape True
# block7a_se_reduce True
# block7a_se_expand True
# block7a_se_excite True
# block7a_project_conv True
# block7a_project_bn True
# top_conv True
# top_bn True
# top_activation True

# %%
transfer_model.compile(

    optimizer=tf.keras.optimizers.Adam(
        learning_rate=1e-5
    ),

    loss="sparse_categorical_crossentropy",

    metrics=["accuracy"]

)

# %%
history_finetune = transfer_model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=3,
    callbacks=[checkpoint_transfer, early_stop]
)
# Out:
# Epoch 1/3
# E0000 00:00:1783287958.901651      25 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/sequential_2_1/efficientnetb0_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 146s 99ms/step - accuracy: 0.9320 - loss: 0.2172 - val_accuracy: 0.9676 - val_loss: 0.0987
# Epoch 2/3
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 131s 97ms/step - accuracy: 0.9534 - loss: 0.1385 - val_accuracy: 0.9694 - val_loss: 0.0900
# Epoch 3/3
# 1358/1358 ━━━━━━━━━━━━━━━━━━━━ 130s 96ms/step - accuracy: 0.9599 - loss: 0.1215 - val_accuracy: 0.9686 - val_loss: 0.0906

# %%
transfer_loss, transfer_accuracy = transfer_model.evaluate(
    validation_dataset
)

print("Validation Accuracy :", transfer_accuracy)

print("Validation Loss :", transfer_loss)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 24s 72ms/step - accuracy: 0.9694 - loss: 0.0900
# Validation Accuracy : 0.9694319367408752
# Validation Loss : 0.0899575799703598

# %%
cnn_loss, cnn_accuracy = cnn_model.evaluate(validation_dataset)
# Out:
# 340/340 ━━━━━━━━━━━━━━━━━━━━ 6s 18ms/step - accuracy: 0.8688 - loss: 0.5003

# %%
import pandas as pd

comparison = pd.DataFrame({

    "Metric":[
        "Validation Accuracy",
        "Validation Loss",
        "Parameters"
    ],

    "Baseline CNN":[

        round(cnn_accuracy,4),

        round(cnn_loss,4),

        cnn_model.count_params()

    ],

    "EfficientNetB0":[

        round(transfer_accuracy,4),

        round(transfer_loss,4),

        transfer_model.count_params()

    ]

})

comparison
# Out:
#                 Metric  Baseline CNN  EfficientNetB0
# 0  Validation Accuracy  8.688000e-01    9.694000e-01
# 1      Validation Loss  5.003000e-01    9.000000e-02
# 2           Parameters  2.225444e+07    4.387273e+06

# %%
plt.figure(figsize=(7,5))

models = ["Baseline CNN","EfficientNetB0"]

accuracies = [

    cnn_accuracy,

    transfer_accuracy

]

plt.bar(models, accuracies)

plt.ylabel("Validation Accuracy")

plt.title("Model Comparison")

plt.show()

# %%
plt.figure(figsize=(7,5))

losses = [

    cnn_loss,

    transfer_loss

]

plt.bar(models, losses)

plt.ylabel("Validation Loss")

plt.title("Loss Comparison")

plt.show()

# %%
if transfer_accuracy > cnn_accuracy:

    transfer_model.save("best_plant_disease_model.keras")

    print("EfficientNetB0 Saved")

else:

    cnn_model.save("best_plant_disease_model.keras")

    print("CNN Saved")
# Out:
# EfficientNetB0 Saved
